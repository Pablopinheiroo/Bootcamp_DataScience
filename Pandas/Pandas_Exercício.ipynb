# %% [markdown]
# # EXERCÍCIOS:

# %%
# Importe o pandas
# Visualize os dados criados na Série
# Crie uma Série com 3 cores diferentes
# Crie uma Série com 3 tipos de fabricantes de carro
# Crie um DataFrame combinando as duas Séries
# Importe o csv "venda-de-carros.csv" em visualize o DataFrame
# Verifique os diferentes tipos de dados do DataFrame
# Verifique as informações estatísticas do DataFrame usando .describe()
# Liste mais informações sobre o DataFrame usando a função info()
# Liste o nome de todas as colunas do DataFrame
# Exiba apenas as 5 primeiras linhas do DataFrame
# Exiba as 5 últimas linhas do DataFrame
# Utilize .loc para selecionar os dados da linha de índice 3 do DataFrame
# Utilize .iloc para exibir os dados que estão na 5° posição do DataFrame
# Selecione a coluna Quilometragem
# Calcule a média da coluna Quilometragem
# Liste os carros que possuem uma quilometragem maior que 100.000
# Agrupe as colunas pelo fabricante e calcule a média das outras colunas
# Converta a coluna Preco para dados numéricos "float64"

# %% [markdown]
# # Importe o pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# # Crie uma Série com 3 cores diferentes

# %%
cores = pd.Series(["Azul", "Verde", "Branco"])

# %% [markdown]
# # Visualize os dados criados na Série

# %%
cores
# Out:
# 0      Azul
# 1     Verde
# 2    Branco
# dtype: object

# %% [markdown]
# # Crie uma Série com 3 tipos de fabricantes de carro

# %%
carros = pd.Series(["Toyota", "BMW", "Ford"])
carros
# Out:
# 0    Toyota
# 1       BMW
# 2      Ford
# dtype: object

# %% [markdown]
# # Crie um DataFrame combinando as duas Séries

# %%
montadora = pd.DataFrame({"Carros": carros, "Cores": cores})
montadora
# Out:
#    Carros   Cores
# 0  Toyota    Azul
# 1     BMW   Verde
# 2    Ford  Branco

# %% [markdown]
# # Importe o csv "venda-de-carros.csv" em visualize o DataFrame

# %%
vendas_de_carro = pd.read_csv("/content/drive/MyDrive/1 Alura/Fora da Alura/Dados/Pandas/venda-de-carros.csv")
vendas_de_carro
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00
# 5     Toyota     Verde          99213       4   R$ 14,500.00
# 6      Honda      Azul          45698       4   R$ 17,500.00
# 7      Honda      Azul          54738       4   R$ 27,000.00
# 8     Toyota    Branco          60000       4   R$ 26,250.00
# 9     Nissan    Branco          31600       4   R$ 19,700.00

# %% [markdown]
# # Verifique os diferentes tipos de dados do DataFrame

# %%
vendas_de_carro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fabricante     10 non-null     object
#  1   Cor            10 non-null     object
#  2   Quilometragem  10 non-null     int64
#  3   Portas         10 non-null     int64
#  4   Preco          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
vendas_de_carro.dtypes
# Out:
# Fabricante       object
# Cor              object
# Quilometragem     int64
# Portas            int64
# Preco            object
# dtype: object

# %% [markdown]
# # Verifique as informações estatísticas do DataFrame usando .describe()

# %%
vendas_de_carro.describe()
# Out:
#        Quilometragem     Portas
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %% [markdown]
# # Liste mais informações sobre o DataFrame usando a função info()

# %%
vendas_de_carro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fabricante     10 non-null     object
#  1   Cor            10 non-null     object
#  2   Quilometragem  10 non-null     int64
#  3   Portas         10 non-null     int64
#  4   Preco          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %% [markdown]
# # Liste o nome de todas as colunas do DataFrame

# %%
vendas_de_carro.columns
# Out:
# Index(['Fabricante', 'Cor', 'Quilometragem', 'Portas', 'Preco'], dtype='object')

# %% [markdown]
# # Exiba apenas as 5 primeiras linhas do DataFrame

# %%
vendas_de_carro.head()
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00

# %% [markdown]
# # Exiba as 5 últimas linhas do DataFrame

# %%
vendas_de_carro
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00
# 5     Toyota     Verde          99213       4   R$ 14,500.00
# 6      Honda      Azul          45698       4   R$ 17,500.00
# 7      Honda      Azul          54738       4   R$ 27,000.00
# 8     Toyota    Branco          60000       4   R$ 26,250.00
# 9     Nissan    Branco          31600       4   R$ 19,700.00

# %%
vendas_de_carro.tail()
# Out:
#   Fabricante     Cor  Quilometragem  Portas         Preco
# 5     Toyota   Verde          99213       4  R$ 14,500.00
# 6      Honda    Azul          45698       4  R$ 17,500.00
# 7      Honda    Azul          54738       4  R$ 27,000.00
# 8     Toyota  Branco          60000       4  R$ 26,250.00
# 9     Nissan  Branco          31600       4  R$ 19,700.00

# %% [markdown]
# # Utilize .loc para selecionar os dados da linha de índice 3 do DataFrame

# %%
vendas_de_carro.loc[3]
# Out:
# Fabricante                 BMW
# Cor                      Preto
# Quilometragem            11179
# Portas                       5
# Preco            R$ 122,000.00
# Name: 3, dtype: object

# %% [markdown]
# # Utilize .iloc para exibir os dados que estão na 5° posição do DataFrame

# %%
vendas_de_carro
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00
# 5     Toyota     Verde          99213       4   R$ 14,500.00
# 6      Honda      Azul          45698       4   R$ 17,500.00
# 7      Honda      Azul          54738       4   R$ 27,000.00
# 8     Toyota    Branco          60000       4   R$ 26,250.00
# 9     Nissan    Branco          31600       4   R$ 19,700.00

# %%
vendas_de_carro.iloc[5]
# Out:
# Fabricante             Toyota
# Cor                     Verde
# Quilometragem           99213
# Portas                      4
# Preco            R$ 14,500.00
# Name: 5, dtype: object

# %% [markdown]
# # Selecione a coluna Quilometragem

# %%
vendas_de_carro['Quilometragem']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Quilometragem, dtype: int64

# %% [markdown]
# # Calcule a média da coluna Quilometragem

# %%
vendas_de_carro['Quilometragem'].mean()
# Out:
# 78601.4

# %% [markdown]
# # Liste os carros que possuem uma quilometragem maior que 100.000

# %%
vendas_de_carro
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00
# 5     Toyota     Verde          99213       4   R$ 14,500.00
# 6      Honda      Azul          45698       4   R$ 17,500.00
# 7      Honda      Azul          54738       4   R$ 27,000.00
# 8     Toyota    Branco          60000       4   R$ 26,250.00
# 9     Nissan    Branco          31600       4   R$ 19,700.00

# %%
vendas_de_carro[vendas_de_carro["Quilometragem"] > 100000]
# Out:
#   Fabricante     Cor  Quilometragem  Portas         Preco
# 0     Toyota  Branco         150043       4  R$ 24,000.00
# 4     Nissan  Branco         213095       4  R$ 13,500.00

# %% [markdown]
# # Agrupe as colunas pelo fabricante e calcule a média das outras colunas

# %%
vendas_de_carro.groupby(["Fabricante"]).mean()
# Out:
# <ipython-input-97-eb0397ffce0a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   vendas_de_carro.groupby(["Fabricante"]).mean()
#             Quilometragem  Portas
# Fabricante
# BMW          11179.000000    5.00
# Honda        62778.333333    4.00
# Nissan      122347.500000    4.00
# Toyota       85451.250000    3.75

# %%
vendas_de_carro
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00
# 5     Toyota     Verde          99213       4   R$ 14,500.00
# 6      Honda      Azul          45698       4   R$ 17,500.00
# 7      Honda      Azul          54738       4   R$ 27,000.00
# 8     Toyota    Branco          60000       4   R$ 26,250.00
# 9     Nissan    Branco          31600       4   R$ 19,700.00

# %% [markdown]
# # Converta a coluna Preco para dados numéricos "float64"

# %%
vendas_de_carro
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00
# 5     Toyota     Verde          99213       4   R$ 14,500.00
# 6      Honda      Azul          45698       4   R$ 17,500.00
# 7      Honda      Azul          54738       4   R$ 27,000.00
# 8     Toyota    Branco          60000       4   R$ 26,250.00
# 9     Nissan    Branco          31600       4   R$ 19,700.00

# %%
vendas_de_carro["Preco"] = vendas_de_carro["Preco"].str.replace("[R$,]", "", regex = True)

# %%
vendas_de_carro["Preco"] = pd.to_numeric(vendas_de_carro["Preco"])

# %%
vendas_de_carro
# Out:
#   Fabricante       Cor  Quilometragem  Portas     Preco
# 0     Toyota    Branco         150043       4   24000.0
# 1      Honda  Vermelho          87899       4   25000.0
# 2     Toyota      Azul          32549       3   27000.0
# 3        BMW     Preto          11179       5  122000.0
# 4     Nissan    Branco         213095       4   13500.0
# 5     Toyota     Verde          99213       4   14500.0
# 6      Honda      Azul          45698       4   17500.0
# 7      Honda      Azul          54738       4   27000.0
# 8     Toyota    Branco          60000       4   26250.0
# 9     Nissan    Branco          31600       4   19700.0

# %%
vendas_de_carro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fabricante     10 non-null     object
#  1   Cor            10 non-null     object
#  2   Quilometragem  10 non-null     int64
#  3   Portas         10 non-null     int64
#  4   Preco          10 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 528.0+ bytes
